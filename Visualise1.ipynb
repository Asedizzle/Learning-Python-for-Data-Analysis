# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %% [markdown]
# We also use the special command %matplotlib inline to ensure that our plots are displayed and integrated within the Jupyter notebook. Without this command, plots may appear as pop-up windows on occasion.

# %%
#List showiwng the yield of apples (tons per hectare) over six years in an Wonderland.
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

plt.plot(yield_apples)

# %%
#To get rid of the output message one can add a comma
x = plt.plot(yield_apples);

# %%
#To show both axes
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

plt.plot(years, yield_apples);

# %%
#To label axis
plt.xlabel("Years")
plt.ylabel("Yield (tons per hectare)")
plt.plot(years, yield_apples)

# %%
#Plotting Multiple Lines
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]
plt.xlabel('Year')
plt.ylabel("Yeild(tons per hectacre)")
plt.plot(years,apples);
plt.plot(years,oranges);
plt.title("Crop yields in Kanto")
#Adding legends
plt.legend(['Apples','Oranges'])

# %%
#Line Markers
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]
plt.xlabel("Year")
plt.ylabel("Yeild(tons per hectacre)")
plt.plot(apples,years, marker= "o")
plt.plot(oranges, years, marker = "*")
plt.title("Crop yields in Kanto")
plt.legend(["Apples","Oranges"])

# %%
Styling Lines and Markers
